# %%
from PIL import Image
image_loc = './images/puppy.jpg'

image = Image.open(image_loc)
image2 = image.resize((650,650))

image2
# Out:
# <PIL.Image.Image image mode=RGB size=650x650>

# %%
image_loc = './images/puppy.jpg'
imsize = 650

'.' + image_loc.split('.')[-2] + '_' + str(imsize) + '.' +image_loc.split('.')[-1]
# Out:
# './images/puppy_650.jpg'
